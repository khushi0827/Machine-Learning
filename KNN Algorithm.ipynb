# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder , MinMaxScaler , StandardScaler
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler ,SMOTE

# %%
CR = pd.read_csv(r"C:\Users\user\Downloads\creditcards.csv")

# %%
CR['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
CR['Class'].unique()
# Out:
# array([0, 1])

# %%
CR.shape
# Out:
# (284807, 31)

# %%
sns.pairplot(CR.iloc[:20000,-3:],hue='Class',palette='pastel')  # red color show default

# %%
CR.duplicated().sum()
# Out:
# np.int64(1081)

# %%
CR.drop_duplicates(inplace=True)

# %%
CR.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
CR.min()
# Out:
# Time        0.000000
# V1        -56.407510
# V2        -72.715728
# V3        -48.325589
# V4         -5.683171
# V5       -113.743307
# V6        -26.160506
# V7        -43.557242
# V8        -73.216718
# V9        -13.434066
# V10       -24.588262
# V11        -4.797473
# V12       -18.683715
# V13        -5.791881
# V14       -19.214325
# V15        -4.498945
# V16       -14.129855
# V17       -25.162799
# V18        -9.498746
# V19        -7.213527
# V20       -54.497720
# V21       -34.830382
# V22       -10.933144
# V23       -44.807735
# V24        -2.836627
# V25       -10.295397
# V26        -2.604551
# V27       -22.565679
# V28       -15.430084
# Amount      0.000000
# Class       0.000000
# dtype: float64

# %%
CR.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='str')

# %%
#for col in CR.columns:  # to remove Outliers
 #   if col.startswith('V'):
  #      CR=CR[CR[col].between(-3,3)]

# %%
CR.shape
# Out:
# (283726, 31)

# %%
CR['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
x,y=CR.drop('Class',axis=1),CR.Class

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
x.drop('Time',inplace=True,axis=1)

# %%
x
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25)

# %%
KNN=KNeighborsClassifier(n_neighbors=10)

# %%
KNN.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
KNN.score(xtrain,ytrain)
# Out:
# 0.9992058046749438

# %%
KNN.score(xtest,ytest)
# Out:
# 0.9991541194383353

# %%
xtest.shape
# Out:
# (70932, 29)

# %%
xytest=pd.concat([xtest,ytest],axis=1)

# %%
xydefault=xytest[xytest['Class']==1]

# %%
print(xydefault.columns)
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='str')

# %%
xdefault,ydefault=xydefault.drop('Class',axis=1),xydefault.Class

# %%
KNN.score(xdefault,ydefault)
# Out:
# 0.5905511811023622

# %%
RUS = RandomUnderSampler()

# %%
underx,undery=RUS.fit_resample(x,y)

# %%
undery.value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
undery.value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
KNN.fit(underx,undery)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
smote=SMOTE()

# %%
SX,SY=smote.fit_resample(x,y)

# %%
SY.value_counts()
# Out:
# Class
# 0    283253
# 1    283253
# Name: count, dtype: int64

# %%
KNN.fit(SX,SY)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
ROS= RandomOverSampler()

# %%
RX,RY=ROS.fit_resample(x,y)

# %%
RY.value_counts()
# Out:
# Class
# 0    283253
# 1    283253
# Name: count, dtype: int64
