# %% [markdown]
# # Multiple Regression

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
BS=pd.read_csv(r"C:\Users\user\Downloads\boston.csv")

# %%
BS.head(5)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    TAX  PTRATIO       B  LSTAT  Price
# 0  296     15.3  396.90   4.98   24.0
# 1  242     17.8  396.90   9.14   21.6
# 2  242     17.8  392.83   4.03   34.7
# 3  222     18.7  394.63   2.94   33.4
# 4  222     18.7  396.90   5.33   36.2

# %%
BS.shape
# Out:
# (506, 15)

# %%
BS.dtypes
# Out:
# Unnamed: 0      int64
# CRIM          float64
# ZN            float64
# INDUS         float64
# CHAS            int64
# NOX           float64
# RM            float64
# AGE           float64
# DIS           float64
# RAD             int64
# TAX             int64
# PTRATIO       float64
# B             float64
# LSTAT         float64
# Price         float64
# dtype: object

# %%
BS.iloc[:,0]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 501    501
# 502    502
# 503    503
# 504    504
# 505    505
# Name: Unnamed: 0, Length: 506, dtype: int64

# %%
BS.drop('Unnamed: 0',axis=1,inplace=True)

# %%
BS.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(BS.corr(),annot=True,fmt='.1g')
# Out:
# <Axes: >

# %%
BS.drop('DIS',axis=1,inplace=True)

# %%
x = BS.drop('Price',axis=1)
y=BS.Price

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25)

# %% [markdown]
# # MODEL

# %%
LR=LinearRegression()

# %%
LR
# Out:
# LinearRegression()

# %%
LR.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([-0.07071628,  0.01248037,  0.11960673,  2.21125578, -9.25261681,
#         4.13742233,  0.0363259 ,  0.36438763, -0.01638595, -0.97591568,
#         0.00957763, -0.54871226])

# %%
len(x.columns)
# Out:
# 12

# %%
LR.intercept_
# Out:
# np.float64(22.51515354160716)

# %%
LR.predict([[0.02729	,0	,7.07,	0	,0.469,	7.185,	61.1, 2,	242,	17.8	,392.83	,4.03	]])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.90940303])

# %%
np.array(BS.iloc[1,:-1]).reshape(1,12)
# Out:
# array([[2.731e-02, 0.000e+00, 7.070e+00, 0.000e+00, 4.690e-01, 6.421e+00,
#         7.890e+01, 2.000e+00, 2.420e+02, 1.780e+01, 3.969e+02, 9.140e+00]])

# %%
np.array(BS.iloc[0,:-1]).reshape(1,12)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02, 4.980e+00]])

# %%
pred=LR.predict(xtest)

# %%
Comparision = pd.DataFrame({'Actual' : ytest , 'Prediction' : pred })

# %%
Comparision.head(2)
# Out:
#      Actual  Prediction
# 286    20.1   21.911427
# 101    26.5   24.078630

# %% [markdown]
# # Performance Matrix

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score , root_mean_squared_error

# %%
print('MSE :'  ,  mean_squared_error(ytest , pred ))
print('RMSE :' ,  root_mean_squared_error(ytest,pred))
print('MAE :'  ,  mean_absolute_error(ytest,pred))
# Out:
# MSE : 25.966667354322546
# RMSE : 5.095749930512931
# MAE : 3.520432684878248

# %%
R2 = r2_score(ytest,pred)
N = len(ytest)
P = xtest.shape[1]

# %%
adjR2 = 1 - ( ( (1-R2)*(N-1) ) / (N-P-1)  )

# %%
print('R2 : ' ,  R2)

print('Adj R2 : ' , adjR2)
# Out:
# R2 :  0.6850834528865084
# Adj R2 :  0.6519343426640356

# %% [markdown]
# # optimizers

# %%
from sklearn.linear_model import Lasso , Ridge , ElasticNet

# %%
L1 = Ridge(alpha=0.9)
L1.fit(xtrain,ytrain)
L1.score(xtest,ytest)
# Out:
# 0.6832030177218624

# %%
L2 = Lasso(alpha=0.01)
L2.fit(xtrain,ytrain)
L2.score(xtest,ytest)
# Out:
# 0.6833485722120964

# %%
print(L1.score(xtrain,ytrain))
print(L1.score(xtest,ytest))
# Out:
# 0.7179793618719703
# 0.6832030177218624
